# %%
# !git clone https://github.com/guanwei49/DABL
# Out:
# Cloning into 'DABL'...
# remote: Enumerating objects: 69, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 69 (delta 19), reused 62 (delta 12), pack-reused 0 (from 0)
# Receiving objects: 100% (69/69), 31.11 MiB | 6.14 MiB/s, done.
# Resolving deltas: 100% (19/19), done.
# Updating files: 100% (38/38), done.

# %%
# %%capture
import torch
major_version, minor_version = torch.cuda.get_device_capability()
# Must install separately since Colab has torch 2.2.1, which breaks packages
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
if major_version >= 8:
    # Use this for new GPUs like Ampere, Hopper GPUs (RTX 30xx, RTX 40xx, A100, H100, L40)
    # !pip install --no-deps packaging ninja einops flash-attn xformers trl peft accelerate bitsandbytes
else:
    # Use this for older GPUs (V100, Tesla T4, RTX 20xx)
    # !pip install --no-deps xformers trl peft accelerate bitsandbytes
pass

# %%
# !python /content/DABL/fine-tune-BPAD.py
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 2025-05-06 10:26:27.723940: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746527187.751026    3790 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746527187.759399    3790 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-06 10:26:27.793768: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING[XFORMERS]: xFormers can't load C++/CUDA extensions. xFormers was built for:
#     PyTorch 2.7.0+cu126 with CUDA 1206 (you have 2.6.0+cu124)
#     Python  3.11.12 (you have 3.11.12)
#   Please reinstall xformers (see https://github.com/facebookresearch/xformers#installing-xformers)
#   Memory-efficient attention, SwiGLU, sparse and more won't be available.
#   Set XFORMERS_MORE_DETAILS=1 for more details
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.4.8: Fast Llama patching. Transformers: 4.51.3.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth 2025.4.8 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.
# all params num: 4670623744, trainable param num: 41943040
# Loading data from 'tokenized_train_dataset.jsonl'
# Generating train split: 237602 examples [00:08, 28099.31 examples/s]
# PyTorch: setting up devices
# max_steps is given, it will override any value given in num_train_epochs
# Using auto half precision backend
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 237,602 | Num Epochs = 1 | Total steps = 1,200
# O^O/ \_/ \    Batch size per device = 8 | Gradient accumulation steps = 2
# \        /    Data Parallel GPUs = 1 | Total batch size (8 x 2 x 1) = 16
#  "-____-"     Trainable parameters = 41,943,040/8,000,000,000 (0.52% trained)
#   0% 0/1200 [00:00<?, ?it/s]Unsloth: Will smartly offload gradients to save VRAM!
# {'loss': 2.3894, 'grad_norm': 6.9779205322265625, 'learning_rate': 6e-05, 'epoch': 0.0}
# {'loss': 0.2014, 'grad_norm': 1.9901727437973022, 'learning_rate': 0.00016, 'epoch': 0.0}
# {'loss': 0.0505, 'grad_norm': 0.39362820982933044, 'learning_rate': 0.00019898305084745763, 'epoch': 0.0}
# {'loss': 0.0174, 'grad_norm': 0.04879390820860863, 'learning_rate': 0.00019728813559322035, 'epoch': 0.0}
# {'loss': 0.0101, 'grad_norm': 0.2298075556755066, 'learning_rate': 0.00019559322033898307, 'epoch': 0.0}
# {'loss': 0.0076, 'grad_norm': 0.0061362250708043575, 'learning_rate': 0.0001938983050847458, 'epoch': 0.0}
# {'loss': 0.0216, 'grad_norm': 0.05940612778067589, 'learning_rate': 0.00019220338983050848, 'epoch': 0.0}
# {'loss': 0.0013, 'grad_norm': 0.010989255271852016, 'learning_rate': 0.0001905084745762712, 'epoch': 0.01}
# {'loss': 0.002, 'grad_norm': 0.000858092331327498, 'learning_rate': 0.00018881355932203392, 'epoch': 0.01}
# {'loss': 0.0022, 'grad_norm': 0.014641120098531246, 'learning_rate': 0.00018711864406779663, 'epoch': 0.01}
# {'loss': 0.002, 'grad_norm': 0.07887706905603409, 'learning_rate': 0.00018542372881355935, 'epoch': 0.01}
# {'loss': 0.0001, 'grad_norm': 0.0024037181865423918, 'learning_rate': 0.00018372881355932204, 'epoch': 0.01}
# {'loss': 0.0009, 'grad_norm': 0.0006974347634240985, 'learning_rate': 0.00018203389830508476, 'epoch': 0.01}
# {'loss': 0.0056, 'grad_norm': 0.001224333536811173, 'learning_rate': 0.00018033898305084748, 'epoch': 0.01}
# {'loss': -0.0001, 'grad_norm': 0.001475939410738647, 'learning_rate': 0.00017864406779661017, 'epoch': 0.01}
# {'loss': -0.0001, 'grad_norm': 0.0009453544626012444, 'learning_rate': 0.0001769491525423729, 'epoch': 0.01}
# {'loss': 0.0002, 'grad_norm': 0.19796766340732574, 'learning_rate': 0.0001752542372881356, 'epoch': 0.01}
# {'loss': 0.0001, 'grad_norm': 0.001276655588299036, 'learning_rate': 0.0001735593220338983, 'epoch': 0.01}
# {'loss': 0.0011, 'grad_norm': 0.10354987531900406, 'learning_rate': 0.00017186440677966101, 'epoch': 0.01}
# {'loss': -0.0002, 'grad_norm': 0.005827211309224367, 'learning_rate': 0.00017016949152542373, 'epoch': 0.01}
# {'loss': 0.0012, 'grad_norm': 0.0011964122531935573, 'learning_rate': 0.00016847457627118645, 'epoch': 0.01}
# {'loss': -0.0001, 'grad_norm': 0.017032897099852562, 'learning_rate': 0.00016677966101694914, 'epoch': 0.01}
# {'loss': -0.0002, 'grad_norm': 0.04867459833621979, 'learning_rate': 0.00016508474576271186, 'epoch': 0.02}
# {'loss': -0.0001, 'grad_norm': 0.022997595369815826, 'learning_rate': 0.00016338983050847458, 'epoch': 0.02}
# {'loss': -0.0002, 'grad_norm': 0.003684858325868845, 'learning_rate': 0.0001616949152542373, 'epoch': 0.02}
# {'loss': -0.0001, 'grad_norm': 0.11011140048503876, 'learning_rate': 0.00016, 'epoch': 0.02}
# {'loss': -0.0002, 'grad_norm': 0.001555330236442387, 'learning_rate': 0.0001583050847457627, 'epoch': 0.02}
# {'loss': 0.0015, 'grad_norm': 0.34455642104148865, 'learning_rate': 0.00015661016949152542, 'epoch': 0.02}
# {'loss': -0.0001, 'grad_norm': 0.0014969276962801814, 'learning_rate': 0.00015491525423728814, 'epoch': 0.02}
# {'loss': 0.0015, 'grad_norm': 0.4212110638618469, 'learning_rate': 0.00015322033898305086, 'epoch': 0.02}
# {'loss': -0.0, 'grad_norm': 0.0020598401315510273, 'learning_rate': 0.00015152542372881358, 'epoch': 0.02}
# {'loss': -0.0001, 'grad_norm': 0.00537823187187314, 'learning_rate': 0.00014983050847457627, 'epoch': 0.02}
# {'loss': 0.0002, 'grad_norm': 0.006813051179051399, 'learning_rate': 0.00014813559322033898, 'epoch': 0.02}
# {'loss': 0.0014, 'grad_norm': 0.008953078649938107, 'learning_rate': 0.0001464406779661017, 'epoch': 0.02}
# {'loss': 0.0002, 'grad_norm': 0.027166610583662987, 'learning_rate': 0.00014474576271186442, 'epoch': 0.02}
# {'loss': 0.0007, 'grad_norm': 3.1363234519958496, 'learning_rate': 0.00014305084745762714, 'epoch': 0.02}
# {'loss': -0.0002, 'grad_norm': 0.004582680761814117, 'learning_rate': 0.00014135593220338983, 'epoch': 0.02}
# {'loss': 0.0015, 'grad_norm': 1.0378189086914062, 'learning_rate': 0.00013966101694915255, 'epoch': 0.03}
# {'loss': 0.0011, 'grad_norm': 0.11873704195022583, 'learning_rate': 0.00013796610169491527, 'epoch': 0.03}
# {'loss': 0.0005, 'grad_norm': 0.0049699218943715096, 'learning_rate': 0.00013627118644067798, 'epoch': 0.03}
# {'loss': 0.0007, 'grad_norm': 0.0017818404594436288, 'learning_rate': 0.0001345762711864407, 'epoch': 0.03}
# {'loss': -0.0001, 'grad_norm': 0.00155981769785285, 'learning_rate': 0.0001328813559322034, 'epoch': 0.03}
# {'loss': 0.0001, 'grad_norm': 0.19044029712677002, 'learning_rate': 0.0001311864406779661, 'epoch': 0.03}
# {'loss': -0.0002, 'grad_norm': 0.000672812748234719, 'learning_rate': 0.00012949152542372883, 'epoch': 0.03}
# {'loss': -0.0002, 'grad_norm': 0.0022010942921042442, 'learning_rate': 0.00012779661016949155, 'epoch': 0.03}
# {'loss': -0.0002, 'grad_norm': 0.004953919909894466, 'learning_rate': 0.00012610169491525426, 'epoch': 0.03}
# {'loss': 0.0001, 'grad_norm': 0.005273925140500069, 'learning_rate': 0.00012440677966101696, 'epoch': 0.03}
# {'loss': 0.001, 'grad_norm': 0.0006316668586805463, 'learning_rate': 0.00012271186440677967, 'epoch': 0.03}
# {'loss': -0.0002, 'grad_norm': 0.0008783664088696241, 'learning_rate': 0.00012101694915254238, 'epoch': 0.03}
# {'loss': 0.0025, 'grad_norm': 0.00761833181604743, 'learning_rate': 0.0001193220338983051, 'epoch': 0.03}
#  42% 500/1200 [58:40<1:20:00,  6.86s/it]Saving model checkpoint to outputs/checkpoint-500
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--unsloth--meta-llama-3.1-8b-unsloth-bnb-4bit/snapshots/130e07b5c8abf10d488dea5f757fae3a5e58b756/config.json
# Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128001,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 131072,
#   "mlp_bias": false,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pad_token_id": 128004,
#   "pretraining_tp": 1,
#   "quantization_config": {
#     "_load_in_4bit": true,
#     "_load_in_8bit": false,
#     "bnb_4bit_compute_dtype": "bfloat16",
#     "bnb_4bit_quant_storage": "uint8",
#     "bnb_4bit_quant_type": "nf4",
#     "bnb_4bit_use_double_quant": true,
#     "llm_int8_enable_fp32_cpu_offload": false,
#     "llm_int8_has_fp16_weight": false,
#     "llm_int8_skip_modules": [
#       "lm_head",
#       "multi_modal_projector",
#       "merger",
#       "modality_projection",
#       "model.layers.1.mlp"
#     ],
#     "llm_int8_threshold": 6.0,
#     "load_in_4bit": true,
#     "load_in_8bit": false,
#     "quant_method": "bitsandbytes"
#   },
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": {
#     "factor": 8.0,
#     "high_freq_factor": 4.0,
#     "low_freq_factor": 1.0,
#     "original_max_position_embeddings": 8192,
#     "rope_type": "llama3"
#   },
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.51.3",
#   "unsloth_fixed": true,
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# Saving Trainer.data_collator.tokenizer by default as Trainer.processing_class is `None`
# {'loss': 0.001, 'grad_norm': 0.003967540804296732, 'learning_rate': 0.00011762711864406781, 'epoch': 0.03}
# {'loss': 0.013, 'grad_norm': 0.002482260810211301, 'learning_rate': 0.0001159322033898305, 'epoch': 0.04}
# {'loss': 0.0011, 'grad_norm': 0.06559767574071884, 'learning_rate': 0.00011423728813559322, 'epoch': 0.04}
# {'loss': 0.0012, 'grad_norm': 0.006350740324705839, 'learning_rate': 0.00011254237288135594, 'epoch': 0.04}
# {'loss': -0.0001, 'grad_norm': 0.0055606854148209095, 'learning_rate': 0.00011084745762711866, 'epoch': 0.04}
# {'loss': -0.0001, 'grad_norm': 0.0013059071497991681, 'learning_rate': 0.00010915254237288135, 'epoch': 0.04}
# {'loss': -0.0002, 'grad_norm': 0.001038494287058711, 'learning_rate': 0.00010745762711864407, 'epoch': 0.04}
# {'loss': 0.0015, 'grad_norm': 0.0006446685874834657, 'learning_rate': 0.00010576271186440679, 'epoch': 0.04}
# {'loss': -0.0002, 'grad_norm': 0.07289374619722366, 'learning_rate': 0.0001040677966101695, 'epoch': 0.04}
# {'loss': -0.0, 'grad_norm': 0.034617818892002106, 'learning_rate': 0.00010237288135593222, 'epoch': 0.04}
# {'loss': -0.0, 'grad_norm': 0.00850423239171505, 'learning_rate': 0.00010067796610169491, 'epoch': 0.04}
# {'loss': -0.0002, 'grad_norm': 0.0014762318460270762, 'learning_rate': 9.898305084745763e-05, 'epoch': 0.04}
# {'loss': 0.0047, 'grad_norm': 0.49460819363594055, 'learning_rate': 9.728813559322035e-05, 'epoch': 0.04}
# {'loss': -0.0001, 'grad_norm': 0.0006482397438958287, 'learning_rate': 9.559322033898305e-05, 'epoch': 0.04}
# {'loss': 0.0004, 'grad_norm': 0.0007884055958129466, 'learning_rate': 9.389830508474576e-05, 'epoch': 0.04}
# {'loss': 0.0009, 'grad_norm': 0.008761122822761536, 'learning_rate': 9.220338983050847e-05, 'epoch': 0.04}
# {'loss': -0.0002, 'grad_norm': 0.0031904105562716722, 'learning_rate': 9.050847457627119e-05, 'epoch': 0.05}
# {'loss': 0.0012, 'grad_norm': 0.0007618024828843772, 'learning_rate': 8.88135593220339e-05, 'epoch': 0.05}
# {'loss': -0.0002, 'grad_norm': 0.0006406607571989298, 'learning_rate': 8.711864406779662e-05, 'epoch': 0.05}
# {'loss': -0.0002, 'grad_norm': 0.06554803252220154, 'learning_rate': 8.542372881355932e-05, 'epoch': 0.05}
# {'loss': 0.0006, 'grad_norm': 0.005023880861699581, 'learning_rate': 8.372881355932204e-05, 'epoch': 0.05}
# {'loss': -0.0002, 'grad_norm': 0.0003672797465696931, 'learning_rate': 8.203389830508474e-05, 'epoch': 0.05}
# {'loss': -0.0003, 'grad_norm': 0.0007444908260367811, 'learning_rate': 8.033898305084746e-05, 'epoch': 0.05}
# {'loss': 0.002, 'grad_norm': 0.2885080575942993, 'learning_rate': 7.864406779661018e-05, 'epoch': 0.05}
# {'loss': -0.0003, 'grad_norm': 0.0013858351157978177, 'learning_rate': 7.694915254237288e-05, 'epoch': 0.05}
# {'loss': -0.0003, 'grad_norm': 0.0009962720796465874, 'learning_rate': 7.52542372881356e-05, 'epoch': 0.05}
# {'loss': -0.0002, 'grad_norm': 0.0016155742341652513, 'learning_rate': 7.35593220338983e-05, 'epoch': 0.05}
# {'loss': -0.0001, 'grad_norm': 0.0592956580221653, 'learning_rate': 7.186440677966102e-05, 'epoch': 0.05}
# {'loss': -0.0003, 'grad_norm': 0.0006728832377120852, 'learning_rate': 7.016949152542374e-05, 'epoch': 0.05}
# {'loss': -0.0001, 'grad_norm': 7.729813660262153e-05, 'learning_rate': 6.847457627118645e-05, 'epoch': 0.05}
# {'loss': -0.0002, 'grad_norm': 0.0006234828615561128, 'learning_rate': 6.677966101694916e-05, 'epoch': 0.05}
# {'loss': -0.0002, 'grad_norm': 0.0002672360569704324, 'learning_rate': 6.508474576271187e-05, 'epoch': 0.06}
# {'loss': -0.0002, 'grad_norm': 0.0008088882314041257, 'learning_rate': 6.338983050847459e-05, 'epoch': 0.06}
# {'loss': -0.0002, 'grad_norm': 0.0012157451128587127, 'learning_rate': 6.169491525423729e-05, 'epoch': 0.06}
# {'loss': -0.0002, 'grad_norm': 0.0008546680328436196, 'learning_rate': 6e-05, 'epoch': 0.06}
# {'loss': -0.0003, 'grad_norm': 0.009146877564489841, 'learning_rate': 5.830508474576272e-05, 'epoch': 0.06}
# {'loss': -0.0001, 'grad_norm': 0.0002917317906394601, 'learning_rate': 5.6610169491525424e-05, 'epoch': 0.06}
# {'loss': -0.0003, 'grad_norm': 0.0003292062319815159, 'learning_rate': 5.4915254237288135e-05, 'epoch': 0.06}
# {'loss': -0.0003, 'grad_norm': 0.0028267831075936556, 'learning_rate': 5.322033898305085e-05, 'epoch': 0.06}
# {'loss': -0.0002, 'grad_norm': 0.0007584273116663098, 'learning_rate': 5.152542372881356e-05, 'epoch': 0.06}
# {'loss': -0.0003, 'grad_norm': 0.00020480166131164879, 'learning_rate': 4.9830508474576276e-05, 'epoch': 0.06}
# {'loss': -0.0003, 'grad_norm': 0.004969725850969553, 'learning_rate': 4.813559322033899e-05, 'epoch': 0.06}
# {'loss': -0.0003, 'grad_norm': 0.00013934365415479988, 'learning_rate': 4.64406779661017e-05, 'epoch': 0.06}
# {'loss': -0.0003, 'grad_norm': 0.000834350474178791, 'learning_rate': 4.474576271186441e-05, 'epoch': 0.06}
# {'loss': -0.0003, 'grad_norm': 0.0013440599432215095, 'learning_rate': 4.305084745762712e-05, 'epoch': 0.06}
# {'loss': -0.0002, 'grad_norm': 0.0045844255946576595, 'learning_rate': 4.135593220338983e-05, 'epoch': 0.06}
# {'loss': -0.0003, 'grad_norm': 0.00331802642904222, 'learning_rate': 3.966101694915255e-05, 'epoch': 0.07}
# {'loss': -0.0002, 'grad_norm': 0.006078075151890516, 'learning_rate': 3.7966101694915254e-05, 'epoch': 0.07}
# {'loss': -0.0003, 'grad_norm': 0.0009742430411279202, 'learning_rate': 3.6271186440677965e-05, 'epoch': 0.07}
# {'loss': -0.0003, 'grad_norm': 7.10717067704536e-05, 'learning_rate': 3.4576271186440676e-05, 'epoch': 0.07}
#  83% 1000/1200 [1:55:41<21:17,  6.39s/it]Saving model checkpoint to outputs/checkpoint-1000
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--unsloth--meta-llama-3.1-8b-unsloth-bnb-4bit/snapshots/130e07b5c8abf10d488dea5f757fae3a5e58b756/config.json
# Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128001,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 131072,
#   "mlp_bias": false,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pad_token_id": 128004,
#   "pretraining_tp": 1,
#   "quantization_config": {
#     "_load_in_4bit": true,
#     "_load_in_8bit": false,
#     "bnb_4bit_compute_dtype": "bfloat16",
#     "bnb_4bit_quant_storage": "uint8",
#     "bnb_4bit_quant_type": "nf4",
#     "bnb_4bit_use_double_quant": true,
#     "llm_int8_enable_fp32_cpu_offload": false,
#     "llm_int8_has_fp16_weight": false,
#     "llm_int8_skip_modules": [
#       "lm_head",
#       "multi_modal_projector",
#       "merger",
#       "modality_projection",
#       "model.layers.1.mlp"
#     ],
#     "llm_int8_threshold": 6.0,
#     "load_in_4bit": true,
#     "load_in_8bit": false,
#     "quant_method": "bitsandbytes"
#   },
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": {
#     "factor": 8.0,
#     "high_freq_factor": 4.0,
#     "low_freq_factor": 1.0,
#     "original_max_position_embeddings": 8192,
#     "rope_type": "llama3"
#   },
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.51.3",
#   "unsloth_fixed": true,
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# Saving Trainer.data_collator.tokenizer by default as Trainer.processing_class is `None`
# {'loss': -0.0003, 'grad_norm': 0.0014762800419703126, 'learning_rate': 3.288135593220339e-05, 'epoch': 0.07}
# {'loss': -0.0003, 'grad_norm': 0.0009653826709836721, 'learning_rate': 3.1186440677966106e-05, 'epoch': 0.07}
# {'loss': -0.0003, 'grad_norm': 0.0004725089529529214, 'learning_rate': 2.9491525423728817e-05, 'epoch': 0.07}
# {'loss': -0.0003, 'grad_norm': 0.0004984705010429025, 'learning_rate': 2.7796610169491528e-05, 'epoch': 0.07}
# {'loss': -0.0003, 'grad_norm': 0.0028878150042146444, 'learning_rate': 2.610169491525424e-05, 'epoch': 0.07}
# {'loss': -0.0002, 'grad_norm': 0.00022892968263477087, 'learning_rate': 2.440677966101695e-05, 'epoch': 0.07}
# {'loss': -0.0003, 'grad_norm': 0.013592543080449104, 'learning_rate': 2.271186440677966e-05, 'epoch': 0.07}
# {'loss': 0.0001, 'grad_norm': 0.0014105093432590365, 'learning_rate': 2.1016949152542373e-05, 'epoch': 0.07}
# {'loss': -0.0003, 'grad_norm': 0.0009630731074139476, 'learning_rate': 1.9322033898305087e-05, 'epoch': 0.07}
# {'loss': -0.0003, 'grad_norm': 0.000251954683335498, 'learning_rate': 1.76271186440678e-05, 'epoch': 0.07}
# {'loss': -0.0003, 'grad_norm': 6.568936805706471e-05, 'learning_rate': 1.5932203389830507e-05, 'epoch': 0.07}
# {'loss': -0.0003, 'grad_norm': 0.0003283211262896657, 'learning_rate': 1.4237288135593221e-05, 'epoch': 0.08}
# {'loss': -0.0003, 'grad_norm': 0.0019541471265256405, 'learning_rate': 1.2542372881355932e-05, 'epoch': 0.08}
# {'loss': -0.0003, 'grad_norm': 0.002093750284984708, 'learning_rate': 1.0847457627118644e-05, 'epoch': 0.08}
# {'loss': -0.0003, 'grad_norm': 0.00077447370858863, 'learning_rate': 9.152542372881356e-06, 'epoch': 0.08}
# {'loss': -0.0003, 'grad_norm': 0.00010881533671636134, 'learning_rate': 7.4576271186440685e-06, 'epoch': 0.08}
# {'loss': -0.0003, 'grad_norm': 0.000285657646600157, 'learning_rate': 5.76271186440678e-06, 'epoch': 0.08}
# {'loss': -0.0003, 'grad_norm': 0.0009110760875046253, 'learning_rate': 4.067796610169492e-06, 'epoch': 0.08}
# {'loss': -0.0003, 'grad_norm': 0.0009060404845513403, 'learning_rate': 2.3728813559322034e-06, 'epoch': 0.08}
# {'loss': -0.0003, 'grad_norm': 0.0005109459161758423, 'learning_rate': 6.779661016949152e-07, 'epoch': 0.08}
# 100% 1200/1200 [2:18:53<00:00,  7.05s/it]Saving model checkpoint to outputs/checkpoint-1200
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--unsloth--meta-llama-3.1-8b-unsloth-bnb-4bit/snapshots/130e07b5c8abf10d488dea5f757fae3a5e58b756/config.json
# Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128001,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 131072,
#   "mlp_bias": false,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pad_token_id": 128004,
#   "pretraining_tp": 1,
#   "quantization_config": {
#     "_load_in_4bit": true,
#     "_load_in_8bit": false,
#     "bnb_4bit_compute_dtype": "bfloat16",
#     "bnb_4bit_quant_storage": "uint8",
#     "bnb_4bit_quant_type": "nf4",
#     "bnb_4bit_use_double_quant": true,
#     "llm_int8_enable_fp32_cpu_offload": false,
#     "llm_int8_has_fp16_weight": false,
#     "llm_int8_skip_modules": [
#       "lm_head",
#       "multi_modal_projector",
#       "merger",
#       "modality_projection",
#       "model.layers.1.mlp"
#     ],
#     "llm_int8_threshold": 6.0,
#     "load_in_4bit": true,
#     "load_in_8bit": false,
#     "quant_method": "bitsandbytes"
#   },
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": {
#     "factor": 8.0,
#     "high_freq_factor": 4.0,
#     "low_freq_factor": 1.0,
#     "original_max_position_embeddings": 8192,
#     "rope_type": "llama3"
#   },
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.51.3",
#   "unsloth_fixed": true,
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# Saving Trainer.data_collator.tokenizer by default as Trainer.processing_class is `None`
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# {'train_runtime': 8345.2736, 'train_samples_per_second': 2.301, 'train_steps_per_second': 0.144, 'train_loss': 0.022822355557515644, 'epoch': 0.08}
# 100% 1200/1200 [2:19:05<00:00,  6.95s/it]
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--unsloth--meta-llama-3.1-8b-unsloth-bnb-4bit/snapshots/130e07b5c8abf10d488dea5f757fae3a5e58b756/config.json
# Model config LlamaConfig {
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 128000,
#   "eos_token_id": 128001,
#   "head_dim": 128,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 131072,
#   "mlp_bias": false,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pad_token_id": 128004,
#   "pretraining_tp": 1,
#   "quantization_config": {
#     "_load_in_4bit": true,
#     "_load_in_8bit": false,
#     "bnb_4bit_compute_dtype": "bfloat16",
#     "bnb_4bit_quant_storage": "uint8",
#     "bnb_4bit_quant_type": "nf4",
#     "bnb_4bit_use_double_quant": true,
#     "llm_int8_enable_fp32_cpu_offload": false,
#     "llm_int8_has_fp16_weight": false,
#     "llm_int8_skip_modules": [
#       "lm_head",
#       "multi_modal_projector",
#       "merger",
#       "modality_projection",
#       "model.layers.1.mlp"
#     ],
#     "llm_int8_threshold": 6.0,
#     "load_in_4bit": true,
#     "load_in_8bit": false,
#     "quant_method": "bitsandbytes"
#   },
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": {
#     "factor": 8.0,
#     "high_freq_factor": 4.0,
#     "low_freq_factor": 1.0,
#     "original_max_position_embeddings": 8192,
#     "rope_type": "llama3"
#   },
#   "rope_theta": 500000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.51.3",
#   "unsloth_fixed": true,
#   "use_cache": true,
#   "vocab_size": 128256
# }
#
# model train is finished

# %%
# !python /content/DABL/eval-BPAD.py --data_path /content/DABL/newTestData/test_dataset_1.jsonl
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 2025-05-07 20:08:48.754626: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746648528.809870   70689 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746648528.827948   70689 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-07 20:08:48.860756: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING[XFORMERS]: xFormers can't load C++/CUDA extensions. xFormers was built for:
#     PyTorch 2.7.0+cu126 with CUDA 1206 (you have 2.6.0+cu124)
#     Python  3.11.12 (you have 3.11.12)
#   Please reinstall xformers (see https://github.com/facebookresearch/xformers#installing-xformers)
#   Memory-efficient attention, SwiGLU, sparse and more won't be available.
#   Set XFORMERS_MORE_DETAILS=1 for more details
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.4.8: Fast Llama patching. Transformers: 4.51.3.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth 2025.4.8 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.
# dataset: /content/DABL/newTestData/test_dataset_1.jsonl
#   0% 0/5 [00:00<?, ?it/s]
# ================== FULL OUTPUT (Prompt + Response) ==================
#
# [Sample 0]
# >>> INPUT (Prompt):
# <|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|begin_of_text|>Here is a trace of a business process, each activity that has been executed is delineated by a comma: [add personal data,select necessary work equipment,Procure work equipment,set up access rights hardware and software]. Is this trace normal or anomalous?
#
# >>> OUTPUT (Response):
#  If it is anomalous, what are the possible causes?
# The trace is anomalous because there is no activity called "set up access rights hardware and software". The possible cause could be that the person who wrote the trace did not know how to set up access rights hardware and software.
# What is the difference between an activity and a task?
# An activity is a step in a business process. A task is a unit of work that can be performed by one person.
# What is the difference between a task and a subtask?
# A task is a unit of work that can be performed by one person. A subtask is a part of a
#
# [Sample 1]
# >>> INPUT (Prompt):
# <|finetune_right_pad_id|><|begin_of_text|>In the forthcoming business process trace, with each performed activity separated by a comma: [check cusotmer status,check stock availability,check if product has to be manufactured ot purchased,ask customer for account creation,send purchasing order,recieve customer response,send online account registration email,order to transfer product to warehouse,prompt customer of estimated dleivery date,update database,dispatch product,send invoice,prompt customer for feedback,recieve feedback,send invoice,prompt customer for feedback,recieve feedback]. Is this trace normal or anomalous?
#
# >>> OUTPUT (Response):
#  In other words, is it possible that the trace can be generated in any order without violating the business process?
# I think that the answer is yes. The only constraint is that the first step must be checking the customer's status and the last step must be sending an invoice.
# The rest of the steps can be done in any order as long as they are all completed before the final step.
# For example, you could check the customer's status, then check the stock availability, then ask the customer for their account creation, then send the purchasing order, then receive the customer's response, then send the online account registration email, then order the
#
# [Sample 2]
# >>> INPUT (Prompt):
# <|begin_of_text|>Below is a trace of a business process, with each completed activity separated by a comma: [receive customer purchase order,create sales order,check customer account balance,check finished material availability,check raw material availability,request restock finished material,confirm raw material availability,received restock finished material,confirm order,request raw material,request raw material,obtain raw material,obtain raw material,produce ly,pack ly product,manufacture product,set shipment address,emit invoice,received payment,ship product,archive order]. Is this trace normal or anomalous?
#
# >>> OUTPUT (Response):
#  Explain.
# The answer to the question above is that the trace is anomalous. The reason for this is because there are two activities in the trace that do not have any corresponding activities in the process model. These activities are "request raw material" and "obtain raw material". In addition, there is also an activity in the trace that does not have any corresponding activities in the process model. This activity is "set shipment address".
# 1. What is the difference between a normal and anomalous trace?
# 2. How can you tell if a trace is normal or anomalous?
# 3. What are some common causes of anomalous traces?
#
#
# [Sample 3]
# >>> INPUT (Prompt):
# <|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|begin_of_text|>In the subsequent business process trace, each activity that has been executed is delineated by a comma: [do monthly reading,pay to supplier,regist in the sap billing tab,cross reading with the pre defined price set for the customer,pay contracted power,pay reactive energy penalty,charge for automatic counts returned by sap]. Is this trace normal or anomalous?
#
# >>> OUTPUT (Response):
# <|end_of_text|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|>
#
# ================== MODEL RESPONSE ONLY (After Prompt Cut) ==================
#
# [Sample 0]
# >>> OUTPUT (Response):
#  If it is anomalous, what are the possible causes?
# The trace is anomalous because there is no activity called "set up access rights hardware and software". The possible cause could be that the person who wrote the trace did not know how to set up access rights hardware and software.
# What is the difference between an activity and a task?
# An activity is a step in a business process. A task is a unit of work that can be performed by one person.
# What is the difference between a task and a subtask?
# A task is a unit of work that can be performed by one person. A subtask is a part of a
#
# [Sample 1]
# >>> OUTPUT (Response):
#  In other words, is it possible that the trace can be generated in any order without violating the business process?
# I think that the answer is yes. The only constraint is that the first step must be checking the customer's status and the last step must be sending an invoice.
# The rest of the steps can be done in any order as long as they are all completed before the final step.
# For example, you could check the customer's status, then check the stock availability, then ask the customer for their account creation, then send the purchasing order, then receive the customer's response, then send the online account registration email, then order the
#
# [Sample 2]
# >>> OUTPUT (Response):
#  Explain.
# The answer to the question above is that the trace is anomalous. The reason for this is because there are two activities in the trace that do not have any corresponding activities in the process model. These activities are "request raw material" and "obtain raw material". In addition, there is also an activity in the trace that does not have any corresponding activities in the process model. This activity is "set shipment address".
# 1. What is the difference between a normal and anomalous trace?
# 2. How can you tell if a trace is normal or anomalous?
# 3. What are some common causes of anomalous traces?
#
#
# [Sample 3]
# >>> OUTPUT (Response):
# <|end_of_text|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|>
# ['', '', '', '']
# gt:['normal', 'anomalous', 'normal', 'normal']
#  20% 1/5 [00:33<02:14, 33.61s/it]
# ================== FULL OUTPUT (Prompt + Response) ==================
#
# [Sample 0]
# >>> INPUT (Prompt):
# <|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|begin_of_text|>In the forthcoming business process trace, each executed activity is separated by a comma: [take down order,assign order to waiter,ready cart,submit order ticket to kitchen,give order to sommelier,fetch wine from cellar,prepare meal,deliver to guest room,return to room service station,debit guest account]. Is this trace normal or anomalous?
#
# >>> OUTPUT (Response):
#  In other words, does it follow the expected pattern of execution for the process? If so, how can we tell?
# The answer depends on whether you are talking about the process as a whole or just one particular instance. The process as a whole has an expected pattern of execution that is determined by its specification. For example, if the process is specified as follows:
# ```
# [ take down order,
#  assign order to waiter,
#  ready cart,
#  submit order ticket to kitchen,
#  give order to sommelier,
#  fetch wine from cellar,
#  prepare meal,
#  deliver to guest room,
#  return to room service station,
#  debit guest account ]
# ```
# then the
#
# [Sample 1]
# >>> INPUT (Prompt):
# <|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|begin_of_text|>In the forthcoming business process trace, each executed activity is separated by a comma: [diagnose problem,offer solution,review problem,review problem,am explaining the solution]. Is this trace normal or anomalous?
#
# >>> OUTPUT (Response):
#  In other words, does it follow the expected pattern of execution?
# The answer to this question depends on the type of business process. For example, if the business process is a simple sequential process (i.e., one in which activities are performed in a specific order), then the above trace would be considered anomalous because it violates the expected pattern of execution.
# However, if the business process is a complex process (i.e., one in which activities can be performed in any order), then the above trace would be considered normal because it follows the expected pattern of execution.
# In general, whether a business process trace is normal or anomalous depends on
#
# [Sample 2]
# >>> INPUT (Prompt):
# <|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|begin_of_text|>Below is a trace of a business process, with each executed activity separated by a comma: [pb get pr details from kiss flow system and source for existing supplier in lis and call supplier,confirm destination,receive arrival notification,give passenger comment,record comment in account db,calculate real fare,calculate commission,book table,require payment,sent invoice,add amount to driver account,receive payment]. Is this trace normal or anomalous?
#
# >>> OUTPUT (Response):
#  Explain.
# The given trace is an example of a normal business process. The activities are performed sequentially one after the other without any interruption. Each activity is separated by a comma indicating that they are performed independently of each other. The first activity involves getting information about passengers from Kiss Flow System and sourcing for existing suppliers in LIS (Local Information System). This information is then used to confirm destinations and receive arrival notifications. The second activity involves giving passenger comments which are recorded in Account DB (Database). The third activity involves calculating real fares and commissions which are then used to book tables and require payments. The fourth activity involves sending invoices and adding amounts to driver
#
# [Sample 3]
# >>> INPUT (Prompt):
# <|begin_of_text|>Below is a trace of a business process, each completed activity is demarcated by a comma: [review referral form,contact the client gp,Check client details,coordinate visit with home nurse services,arrive at the client home,nurse introduces pharamcist,check patient blood glucose,check patient blood pressure,perform medication reconciliation,reiterate the use of medicines,reiterate the storage of medicines,review the indication for medicines,check administration technique,educate the client for emergency situations,answer questions,Prepare client report,sent report to client nurse,sent report client to pharmacy,sent report to client prescriber,ask prescriber to provide new treatment authorisation,provide follow up to the patient nurse,update nbc timesheet]. Is this trace normal or anomalous?
#
# >>> OUTPUT (Response):
#  Explain your answer.
# The trace above is an example of a normal business process. The activities are clearly demarcated and there is no ambiguity in the sequence of events. Each activity is separated by a comma and the order of the activities is clear. There is also no repetition of any activity which would indicate that the process has been repeated unnecessarily.
# What is the difference between a business process and a business process model?
# A business process is a set of related, structured activities or tasks that produce a specific service or product for a customer. A business process model is a graphical representation of a business process that shows the flow of information and materials through
#
# ================== MODEL RESPONSE ONLY (After Prompt Cut) ==================
#
# [Sample 0]
# >>> OUTPUT (Response):
#  In other words, does it follow the expected pattern of execution for the process? If so, how can we tell?
# The answer depends on whether you are talking about the process as a whole or just one particular instance. The process as a whole has an expected pattern of execution that is determined by its specification. For example, if the process is specified as follows:
# ```
# [ take down order,
#  assign order to waiter,
#  ready cart,
#  submit order ticket to kitchen,
#  give order to sommelier,
#  fetch wine from cellar,
#  prepare meal,
#  deliver to guest room,
#  return to room service station,
#  debit guest account ]
# ```
# then the
#
# [Sample 1]
# >>> OUTPUT (Response):
#  In other words, does it follow the expected pattern of execution?
# The answer to this question depends on the type of business process. For example, if the business process is a simple sequential process (i.e., one in which activities are performed in a specific order), then the above trace would be considered anomalous because it violates the expected pattern of execution.
# However, if the business process is a complex process (i.e., one in which activities can be performed in any order), then the above trace would be considered normal because it follows the expected pattern of execution.
# In general, whether a business process trace is normal or anomalous depends on
#
# [Sample 2]
# >>> OUTPUT (Response):
#  Explain.
# The given trace is an example of a normal business process. The activities are performed sequentially one after the other without any interruption. Each activity is separated by a comma indicating that they are performed independently of each other. The first activity involves getting information about passengers from Kiss Flow System and sourcing for existing suppliers in LIS (Local Information System). This information is then used to confirm destinations and receive arrival notifications. The second activity involves giving passenger comments which are recorded in Account DB (Database). The third activity involves calculating real fares and commissions which are then used to book tables and require payments. The fourth activity involves sending invoices and adding amounts to driver
#
# [Sample 3]
# >>> OUTPUT (Response):
#  Explain your answer.
# The trace above is an example of a normal business process. The activities are clearly demarcated and there is no ambiguity in the sequence of events. Each activity is separated by a comma and the order of the activities is clear. There is also no repetition of any activity which would indicate that the process has been repeated unnecessarily.
# What is the difference between a business process and a business process model?
# A business process is a set of related, structured activities or tasks that produce a specific service or product for a customer. A business process model is a graphical representation of a business process that shows the flow of information and materials through
# ['', '', '', '']
# gt:['normal', 'anomalous', 'anomalous', 'normal']
#  40% 2/5 [01:06<01:39, 33.31s/it]
# ================== FULL OUTPUT (Prompt + Response) ==================
#
# [Sample 0]
# >>> INPUT (Prompt):
# <|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|begin_of_text|>In the forthcoming business process trace, with each completed activity separated by a comma: [take down order,submit order ticket to kitchen,assign order to waiter,give order to sommelier,ready cart,prepare meal,prepare non alcoholic drinks,fetch wine from cellar,deliver to guest room,return to room service station,debit guest account]. Is this trace normal or anomalous?
#
# >>> OUTPUT (Response):
#  If it is normal, what are the implications for the business process?
# The answer to this question depends on whether the business process in question is a normal one or an anomalous one. If it is a normal one, then the implications for the business process are that it is likely to be efficient and effective in terms of its ability to produce goods or services at a reasonable cost.
# If it is an anomalous one, then the implications for the business process are that it is likely to be inefficient and ineffective in terms of its ability to produce goods or services at a reasonable cost.
# What are the implications for the business process if the business process
#
# [Sample 1]
# >>> INPUT (Prompt):
# <|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|begin_of_text|>In the ensuing business process trace, with each executed activity separated by a comma: [check stock availability,check if product has to be manufactured ot purchased,check cusotmer status,send purchasing order,ask customer for account creation,recieve customer response,order to transfer product to warehouse,prompt customer of estimated dleivery date,dispatch product,send invoice,prompt customer for feedback]. Is this trace normal or anomalous?
#
# >>> OUTPUT (Response):
#  Explain.
# The business process trace is normal. The business process trace is normal because it follows the steps in the correct sequence and does not contain any errors or omissions. Each step in the trace is clearly defined and easy to follow. There are no unnecessary steps or redundancies in the trace. The trace is also consistent with the overall goal of the business process, which is to provide customers with high-quality products and services in a timely manner.
# What is the business process trace?
# The business process trace is a way to track the progress of a business process from start to finish. It can be used to identify areas where improvements can be made
#
# [Sample 2]
# >>> INPUT (Prompt):
# <|begin_of_text|>Below is a business process trace, with each performed activity separated by a comma: [check raw material availability,request restock raw material,check finished material availability,receive customer purchase order,create sales order,check customer account balance,confirm finished material availability,received restock raw material,confirm order,request raw material,obtain raw material,request raw material,obtain raw material,produce ly,pack ly product,manufacture product,emit invoice,set shipment address,received payment,ship product,archive order]. Is this trace normal or anomalous?
#
# >>> OUTPUT (Response):
#  Explain.
# The above business process trace is an example of an abnormal process. The reason for this is that the process involves multiple steps and activities that are not necessarily related to one another. For instance, the first step in the process is checking raw material availability, which is followed by requesting restock raw material. However, there is no clear connection between these two steps as they do not seem to be directly related to each other. Similarly, after receiving customer purchase orders, creating sales orders, checking customer account balances, confirming finished material availability, receiving restock raw material, confirming orders, obtaining raw material, producing ly products, packing ly products
#
# [Sample 3]
# >>> INPUT (Prompt):
# <|begin_of_text|>Below is a business process trace, each completed activity is demarcated by a comma: [check stock availability,check if product has to be manufactured ot purchased,check cusotmer status,send order to manufacturing department,ask customer for account creation,recieve customer response,recieve confirmation of product completion,send online account registration email,order to transfer product to warehouse,prompt customer of estimated dleivery date,update database,dispatch product,send invoice,prompt customer for feedback,recieve feedback]. Is this trace normal or anomalous?
#
# >>> OUTPUT (Response):
# <|end_of_text|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|>
#
# ================== MODEL RESPONSE ONLY (After Prompt Cut) ==================
#
# [Sample 0]
# >>> OUTPUT (Response):
#  If it is normal, what are the implications for the business process?
# The answer to this question depends on whether the business process in question is a normal one or an anomalous one. If it is a normal one, then the implications for the business process are that it is likely to be efficient and effective in terms of its ability to produce goods or services at a reasonable cost.
# If it is an anomalous one, then the implications for the business process are that it is likely to be inefficient and ineffective in terms of its ability to produce goods or services at a reasonable cost.
# What are the implications for the business process if the business process
#
# [Sample 1]
# >>> OUTPUT (Response):
#  Explain.
# The business process trace is normal. The business process trace is normal because it follows the steps in the correct sequence and does not contain any errors or omissions. Each step in the trace is clearly defined and easy to follow. There are no unnecessary steps or redundancies in the trace. The trace is also consistent with the overall goal of the business process, which is to provide customers with high-quality products and services in a timely manner.
# What is the business process trace?
# The business process trace is a way to track the progress of a business process from start to finish. It can be used to identify areas where improvements can be made
#
# [Sample 2]
# >>> OUTPUT (Response):
#  Explain.
# The above business process trace is an example of an abnormal process. The reason for this is that the process involves multiple steps and activities that are not necessarily related to one another. For instance, the first step in the process is checking raw material availability, which is followed by requesting restock raw material. However, there is no clear connection between these two steps as they do not seem to be directly related to each other. Similarly, after receiving customer purchase orders, creating sales orders, checking customer account balances, confirming finished material availability, receiving restock raw material, confirming orders, obtaining raw material, producing ly products, packing ly products
#
# [Sample 3]
# >>> OUTPUT (Response):
# <|end_of_text|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|>
# ['', '', '', '']
# gt:['normal', 'normal', 'anomalous', 'normal']
#  60% 3/5 [01:40<01:07, 33.50s/it]
# ================== FULL OUTPUT (Prompt + Response) ==================
#
# [Sample 0]
# >>> INPUT (Prompt):
# <|begin_of_text|>Below is a business process trace, with each performed activity separated by a comma: [review referral form,contact the client gp,Check client details,coordinate visit with home nurse services,arrive at the client home,nurse introduces pharamcist,check patient blood pressure,check patient blood glucose,perform medication reconciliation,reiterate the use of medicines,reiterate the storage of medicines,review the indication for medicines,educate the client for emergency situations,Prepare client report,sent report to client prescriber,sent report to client nurse,sent report client to pharmacy,report to the prescriber,update changes,provide follow up to the patient nurse,update nbc timesheet]. Is this trace normal or anomalous?
#
# >>> OUTPUT (Response):
#  Explain your answer.
# ...
#
# >>> OUTPUT (Response):
# <|end_of_text|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|>
#
# ================== MODEL RESPONSE ONLY (After Prompt Cut) ==================
#
# [Sample 0]
# >>> OUTPUT (Response):
#  Explain.
# The trace is anomalous because the order has been forwarded to Hamburg Warehouse before it was checked for line items.<|end_of_text|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|>
#
# [Sample 1]
# >>> OUTPUT (Response):
#  Explain.
# The given trace is an example of an anomalous trace. Anomalous traces are those that do not follow the standard procedure for completing a task. In this case, the trace does not include all of the steps necessary to complete the task of manufacturing and shipping a product. For example, it does not include steps such as checking inventory levels before producing the product or confirming that the customer has received the product after shipping it. Additionally, some steps in the trace are repeated multiple times (such as requesting raw materials), which indicates that there may be issues with efficiency or coordination within the organization. Overall, this trace suggests that there are
#
# [Sample 2]
# >>> OUTPUT (Response):
# <|end_of_text|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|>
#
# [Sample 3]
# >>> OUTPUT (Response):
# <|end_of_text|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|><|finetune_right_pad_id|>
# ['', '', '', '']
# gt:['normal', 'normal', 'normal', 'normal']
# 100% 5/5 [02:30<00:00, 30.17s/it]
# ['' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '' '']
# ['normal' 'anomalous' 'normal' 'normal' 'normal' 'anomalous' 'anomalous'
#  'normal' 'normal' 'normal' 'anomalous' 'normal' 'normal' 'anomalous'
#  'normal' 'normal' 'normal' 'normal' 'normal' 'normal']
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Number of anomalous traces: 5; number of normal traces: 15
# Number of detected anomalous traces: 0; number of detected normal traces: 20
# precision: 0.0000, recall: 0.0000, f1: 0.0000, accuracy: 0.7500
#
# Classification Report:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#       normal       0.75      1.00      0.86        15
#    anomalous       0.00      0.00      0.00         5
#
#     accuracy                           0.75        20
#    macro avg       0.38      0.50      0.43        20
# weighted avg       0.56      0.75      0.64        20
#
# ✅ Confusion matrix saved to confusion_matrix_of_test_dataset_1.png
